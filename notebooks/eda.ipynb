# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/final/GME_features.csv", parse_dates=["time"])
df.set_index("time", inplace=True)

# %%
# Plot sentiment over time
plt.figure(figsize=(12, 5))
df[["reddit_sent", "twitter_sent"]].plot()
plt.title("Hourly Sentiment")
plt.ylabel("Sentiment Score")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Feature Correlations")
plt.show()

# %%
df = pd.read_csv('../data/final/GME_features.csv', parse_dates=['time'])

# Check for non-zero sentiment values
print(df[['reddit_sent', 'twitter_sent']].describe())

# Plot again (zoomed for better visibility)
df[['reddit_sent', 'twitter_sent']].plot(figsize=(12, 5), title="Hourly Sentiment")
# Out:
#        reddit_sent  twitter_sent
# count        140.0         140.0
# mean           0.0           0.0
# std            0.0           0.0
# min            0.0           0.0
# 25%            0.0           0.0
# 50%            0.0           0.0
# 75%            0.0           0.0
# max            0.0           0.0
# <Axes: title={'center': 'Hourly Sentiment'}>

# %%
df = pd.read_csv("../data/processed/reddit_GME.csv")
print(df[["sentiment_compound", "content"]].describe())
print(df[["sentiment_compound", "content"]].head(10))
# Out:
#        sentiment_compound
# count          100.000000
# mean             0.245819
# std              0.443677
# min             -0.977100
# 25%              0.000000
# 50%              0.377550
# 75%              0.527350
# max              0.998900
#    sentiment_compound                                            content
# 0              0.9370  Should you buy the dip? I analyzed all S&P 500...
# 1              0.4278      GME YOLO update — Apr 16 2021 — final update.
# 2              0.4278                     GME YOLO update — Jan 28 2021.
# 3              0.4278              GME YOLO month-end update — Jan 2021.
# 4              0.4278                     GME YOLO update — Feb 19 2021.
# 5              0.4278                      GME YOLO update — Feb 1 2021.
# 6              0.1027  GME reached ,950 seconds before halt. I was wa...
# 7              0.5329  GME Stock Split SEC Filing. [ [I don't want to...
# ...

# %%
import json

# FIXED: specify encoding
with open("../data/social/twitter_GME.json", encoding="utf-8") as f:
    data = json.load(f)

print(f"Loaded {len(data)} tweets.")
data[:3]
# Out:
# Loaded 99 tweets.
# [{'edit_history_tweet_ids': ['1941174405213847558'],
#   'text': '$RDDT is a big hit in our community!\n\n.&lt;;~https://t.co/JuXMP3IZJC\n\n$NVDA $AAPL $TSLA $GME $GWAV $AMC $SPY $HOLO $FSRN $NVDA $DUO https://t.co/vdPSgqQpi3',
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0,
#    'bookmark_count': 0,
#    'impression_count': 3},
#   'author_id': '1938328184392744960',
#   'created_at': '2025-07-04T16:36:58.000Z',
#   'id': '1941174405213847558'},
#  {'edit_history_tweet_ids': ['1941174384879862127'],
#   'text': 'Our group chat was on point with that $RZLV pump—straight fire! 🔥 Huge props to the free trial squad that snagged the alert. \n➡️https://t.co/tOM3nmVVYI\n$AAPL $QQQ $RENT $GME $TTWO $AMAT $WMT $CBRL $JDZG $VKTX $FFIE $AMC $SPY $GNS https://t.co/3JdJrvwpVl',
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0,
#    'bookmark_count': 0,
# ...
